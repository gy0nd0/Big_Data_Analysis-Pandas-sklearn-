# %%
import pandas as pd
import numpy as np
df=pd.read_csv('spam (1).csv')

# %%
df
# Out:
#       Unnamed: 0 target                                               text
# 0              0    ham  Go until jurong point, crazy.. Available only ...
# 1              1    ham                      Ok lar... Joking wif u oni...
# 2              2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3              3    ham  U dun say so early hor... U c already then say...
# 4              4    ham  Nah I don't think he goes to usf, he lives aro...
# ...          ...    ...                                                ...
# 5569        5569   spam  This is the 2nd time we have tried 2 contact u...
# 5570        5570    ham               Will ü b going to esplanade fr home?
# 5571        5571    ham  Pity, * was in mood for that. So...any other s...
# 5572        5572    ham  The guy did some bitching but I acted like i'd...
# 5573        5573    ham                         Rofl. Its true to its name
#
# [5574 rows x 3 columns]

# %%
df['lower'] = df['target'].str.lower()

# %%
df
# Out:
#       Unnamed: 0 target                                               text  \
# 0              0    ham  Go until jurong point, crazy.. Available only ...
# 1              1    ham                      Ok lar... Joking wif u oni...
# 2              2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3              3    ham  U dun say so early hor... U c already then say...
# 4              4    ham  Nah I don't think he goes to usf, he lives aro...
# ...          ...    ...                                                ...
# 5569        5569   spam  This is the 2nd time we have tried 2 contact u...
# 5570        5570    ham               Will ü b going to esplanade fr home?
# 5571        5571    ham  Pity, * was in mood for that. So...any other s...
# 5572        5572    ham  The guy did some bitching but I acted like i'd...
# 5573        5573    ham                         Rofl. Its true to its name
#
#      lower
# 0      ham
# 1      ham
# 2     spam
# 3      ham
# ...

# %%
df['upper'] = df['target'].str.upper()

# %%
df
# Out:
#       Unnamed: 0 target                                               text  \
# 0              0    ham  Go until jurong point, crazy.. Available only ...
# 1              1    ham                      Ok lar... Joking wif u oni...
# 2              2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3              3    ham  U dun say so early hor... U c already then say...
# 4              4    ham  Nah I don't think he goes to usf, he lives aro...
# ...          ...    ...                                                ...
# 5569        5569   spam  This is the 2nd time we have tried 2 contact u...
# 5570        5570    ham               Will ü b going to esplanade fr home?
# 5571        5571    ham  Pity, * was in mood for that. So...any other s...
# 5572        5572    ham  The guy did some bitching but I acted like i'd...
# 5573        5573    ham                         Rofl. Its true to its name
#
#      lower upper
# 0      ham   HAM
# 1      ham   HAM
# ...

# %%
df['Cap'] = df['target'].str.capitalize()

# %%
df
# Out:
#       Unnamed: 0 target                                               text  \
# 0              0    ham  Go until jurong point, crazy.. Available only ...
# 1              1    ham                      Ok lar... Joking wif u oni...
# 2              2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3              3    ham  U dun say so early hor... U c already then say...
# 4              4    ham  Nah I don't think he goes to usf, he lives aro...
# ...          ...    ...                                                ...
# 5569        5569   spam  This is the 2nd time we have tried 2 contact u...
# 5570        5570    ham               Will ü b going to esplanade fr home?
# 5571        5571    ham  Pity, * was in mood for that. So...any other s...
# 5572        5572    ham  The guy did some bitching but I acted like i'd...
# 5573        5573    ham                         Rofl. Its true to its name
#
#      lower upper   Cap
# 0      ham   HAM   Ham
# ...

# %%
df['title'] = df['text'].str.title()

# %%
df
#띄어쓰기 별로 대문자화
# Out:
#       Unnamed: 0 target                                               text  \
# 0              0    ham  Go until jurong point, crazy.. Available only ...
# 1              1    ham                      Ok lar... Joking wif u oni...
# 2              2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3              3    ham  U dun say so early hor... U c already then say...
# 4              4    ham  Nah I don't think he goes to usf, he lives aro...
# ...          ...    ...                                                ...
# 5569        5569   spam  This is the 2nd time we have tried 2 contact u...
# 5570        5570    ham               Will ü b going to esplanade fr home?
# 5571        5571    ham  Pity, * was in mood for that. So...any other s...
# 5572        5572    ham  The guy did some bitching but I acted like i'd...
# 5573        5573    ham                         Rofl. Its true to its name
#
# ...

# %%
df['Swap'] = df['text'].str.swapcase()

# %%
df
# Out:
#       Unnamed: 0 target                                               text  \
# 0              0    ham  Go until jurong point, crazy.. Available only ...
# 1              1    ham                      Ok lar... Joking wif u oni...
# 2              2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3              3    ham  U dun say so early hor... U c already then say...
# 4              4    ham  Nah I don't think he goes to usf, he lives aro...
# ...          ...    ...                                                ...
# 5569        5569   spam  This is the 2nd time we have tried 2 contact u...
# 5570        5570    ham               Will ü b going to esplanade fr home?
# 5571        5571    ham  Pity, * was in mood for that. So...any other s...
# 5572        5572    ham  The guy did some bitching but I acted like i'd...
# 5573        5573    ham                         Rofl. Its true to its name
#
# ...

# %%
df[['split1','split2','split3']] = df['text'].str.split(' ',n=2,expand = True)

# %%
df
# Out:
#       Unnamed: 0 target                                               text  \
# 0              0    ham  Go until jurong point, crazy.. Available only ...
# 1              1    ham                      Ok lar... Joking wif u oni...
# 2              2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3              3    ham  U dun say so early hor... U c already then say...
# 4              4    ham  Nah I don't think he goes to usf, he lives aro...
# ...          ...    ...                                                ...
# 5569        5569   spam  This is the 2nd time we have tried 2 contact u...
# 5570        5570    ham               Will ü b going to esplanade fr home?
# 5571        5571    ham  Pity, * was in mood for that. So...any other s...
# 5572        5572    ham  The guy did some bitching but I acted like i'd...
# 5573        5573    ham                         Rofl. Its true to its name
#
# ...

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np

train = pd.read_csv('trainby.csv')
test = pd.read_csv('testby.csv')

# %%
from datetime import datetime
import calendar

# %%
train['date']=train['datetime'].apply(lambda x:x.split()[0])

train['weekday']=train['date'].apply(lambda dateString:calendar.day_name[datetime.strptime(dateString,"%Y-%m-%d").weekday()])

# %%
train
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count        date  \
# 0      14.395        81     0.0000       3          13     16  2011-01-01
# 1      13.635        80     0.0000       8          32     40  2011-01-01
# 2      13.635        80     0.0000       5          27     32  2011-01-01
# 3      14.395        75     0.0000       3          10     13  2011-01-01
# 4      14.395        75     0.0000       0           1      1  2011-01-01
# ...       ...       ...        ...     ...         ...    ...         ...
# 10881  19.695        50    26.0027       7         329    336  2012-12-19
# 10882  17.425        57    15.0013      10         231    241  2012-12-19
# 10883  15.910        61    15.0013       4         164    168  2012-12-19
# 10884  17.425        61     6.0032      12         117    129  2012-12-19
# 10885  16.665        66     8.9981       4          84     88  2012-12-19
#
#          weekday
# 0       Saturday
# 1       Saturday
# 2       Saturday
# 3       Saturday
# 4       Saturday
# ...          ...
# 10881  Wednesday
# 10882  Wednesday
# 10883  Wednesday
# 10884  Wednesday
# 10885  Wednesday
#
# [10886 rows x 14 columns]

# %%
drop_features = ['casual','datetime','date','windspeed']

# %%
train_fin =train.drop(drop_features, axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
train_fin_X=train_fin[['season','holiday','workingday','weather','temp','atemp','weekday','registered']]

# %%
train_fin_X
# Out:
#        season  holiday  workingday  weather   temp   atemp    weekday  \
# 0           1        0           0        1   9.84  14.395   Saturday
# 1           1        0           0        1   9.02  13.635   Saturday
# 2           1        0           0        1   9.02  13.635   Saturday
# 3           1        0           0        1   9.84  14.395   Saturday
# 4           1        0           0        1   9.84  14.395   Saturday
# ...       ...      ...         ...      ...    ...     ...        ...
# 10881       4        0           1        1  15.58  19.695  Wednesday
# 10882       4        0           1        1  14.76  17.425  Wednesday
# 10883       4        0           1        1  13.94  15.910  Wednesday
# 10884       4        0           1        1  13.94  17.425  Wednesday
# 10885       4        0           1        1  13.12  16.665  Wednesday
#
#        registered
# 0              13
# 1              32
# 2              27
# 3              10
# 4               1
# ...           ...
# 10881         329
# 10882         231
# 10883         164
# 10884         117
# 10885          84
#
# [10886 rows x 8 columns]

# %%
train_fin_X['weekday'] = train_fin['weekday'].map({'Sunday':1,
                                      'Monday':2,
                                      'Tuesday':3,
                                      'Wednesday':4,
                                      'Thursday' : 5,
                                      'Friday':6,
                                      'Saturday':7})
# Out:
# <ipython-input-11-1addeef10165>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_fin_X['weekday'] = train_fin['weekday'].map({'Sunday':1,

# %%
train_fin_X
# Out:
#        season  holiday  workingday  weather   temp   atemp  weekday  \
# 0           1        0           0        1   9.84  14.395        7
# 1           1        0           0        1   9.02  13.635        7
# 2           1        0           0        1   9.02  13.635        7
# 3           1        0           0        1   9.84  14.395        7
# 4           1        0           0        1   9.84  14.395        7
# ...       ...      ...         ...      ...    ...     ...      ...
# 10881       4        0           1        1  15.58  19.695        4
# 10882       4        0           1        1  14.76  17.425        4
# 10883       4        0           1        1  13.94  15.910        4
# 10884       4        0           1        1  13.94  17.425        4
# 10885       4        0           1        1  13.12  16.665        4
#
#        registered
# 0              13
# 1              32
# 2              27
# 3              10
# 4               1
# ...           ...
# 10881         329
# 10882         231
# 10883         164
# 10884         117
# 10885          84
#
# [10886 rows x 8 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(train_fin_X)
# Out:
# StandardScaler()

# %%
X_train, X_test, y_train, y_test = train_test_split(train_fin_X, train_fin['count'],test_size=0.3, random_state=111)

# %%
from sklearn.linear_model import LinearRegression

ln_reg_model = LinearRegression()

# %%
ln_reg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
pred_train= ln_reg_model.predict(X_train)

# %%
pred_train
# Out:
# array([161.99043389, 164.1595928 ,  74.32488614, ..., 320.22532135,
#        108.37206883,  31.97586857])

# %%
pred_test=ln_reg_model.predict(X_test)

# %%
pred_test
# Out:
# array([195.89858915,  85.31869481,  64.28955633, ..., 349.18679524,
#        115.86150824,  62.54285915])

# %%
from sklearn.metrics import mean_squared_error

# %%
mse_train=mean_squared_error(y_true = y_train, y_pred=ln_reg_model.predict(X_train))
mse_test=mean_squared_error(y_true = y_test, y_pred=ln_reg_model.predict(X_test))

# %%
print(mse_train)
print(mse_test)
# Out:
# 1197.734628318018
# 1304.6595296280125

# %%
#registered를 추가했더니 큰 폭으로 작아지는 모습이다.
